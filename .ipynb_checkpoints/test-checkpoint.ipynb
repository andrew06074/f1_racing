# %%
# import pandas as pd 

import pandas as pd 
d = pd.read_csv("test.txt", sep="\t",names=['POS','NO','DRIVER','CAR','Q1','Q2','Q3','LAPS'])

# %%
# Out:
#     POS  NO            DRIVER                           CAR        Q1  \
# 0     1  16   Charles Leclerc                       FERRARI  1:31.471
# 1     2   1    Max Verstappen          RED BULL RACING RBPT  1:31.785
# 2     3  55      Carlos Sainz                       FERRARI  1:31.567
# 3     4  11      Sergio Perez          RED BULL RACING RBPT  1:32.311
# 4     5  44    Lewis Hamilton                      MERCEDES  1:32.285
# 5     6  77   Valtteri Bottas            ALFA ROMEO FERRARI  1:31.919
# 6     7  20   Kevin Magnussen                  HAAS FERRARI  1:31.955
# 7     8  14   Fernando Alonso                ALPINE RENAULT  1:32.346
# 8     9  63    George Russell                      MERCEDES  1:32.269
# 9    10  10      Pierre Gasly               ALPHATAURI RBPT  1:32.096
# 10   11  31      Esteban Ocon                ALPINE RENAULT  1:32.041
# 11   12  47   Mick Schumacher                  HAAS FERRARI  1:32.380
# ...
